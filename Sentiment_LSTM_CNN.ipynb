# %% [markdown]
# <a href="https://colab.research.google.com/github/shikhar00778/toxic-comment-classification/blob/master/Sentiment_LSTM_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle/8076/all.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1558200265&Signature=sDXLIF7bM5jdxIr9CM%2BTrqc0gsTLSDCZDBDrL%2F6C0v3gsoowAjhu0x0s9%2FVSYwFk%2F%2BoXmCdpVlcSlgnWOgOYCu1dokohj2LQOuBtTeQMOcJCWG20X1uj6E1eDIGWhoxHJGY66DkHCFMEbTjgL9vK%2FLLOBFhw7MZ7wwTiCiZNxMTQ%2F45XFj7xx6sefyX%2BuLNfvAgiGH9dTzoZaDfs28fYMsPP4gG5xlwYNRER%2FgNSIQR7X3xmIbPb2W53dvSiRzFTG4hCwXaeZwXETTNW8l%2Fv5WGAN8cVSKha8K9S6n6e0I5Nny5SNpQuHM7pOctUxE2zqpuV9SXMhVr99dFKIolEkA%3D%3D&response-content-disposition=attachment%3B+filename%3Djigsaw-toxic-comment-classification-challenge.zip" -O "jigsaw-toxic-comment-classification-challenge.zip" -c
# Out:
# --2019-05-17 16:10:46--  https://storage.googleapis.com/kaggle-competitions-data/kaggle/8076/all.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1558200265&Signature=sDXLIF7bM5jdxIr9CM%2BTrqc0gsTLSDCZDBDrL%2F6C0v3gsoowAjhu0x0s9%2FVSYwFk%2F%2BoXmCdpVlcSlgnWOgOYCu1dokohj2LQOuBtTeQMOcJCWG20X1uj6E1eDIGWhoxHJGY66DkHCFMEbTjgL9vK%2FLLOBFhw7MZ7wwTiCiZNxMTQ%2F45XFj7xx6sefyX%2BuLNfvAgiGH9dTzoZaDfs28fYMsPP4gG5xlwYNRER%2FgNSIQR7X3xmIbPb2W53dvSiRzFTG4hCwXaeZwXETTNW8l%2Fv5WGAN8cVSKha8K9S6n6e0I5Nny5SNpQuHM7pOctUxE2zqpuV9SXMhVr99dFKIolEkA%3D%3D&response-content-disposition=attachment%3B+filename%3Djigsaw-toxic-comment-classification-challenge.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.195.128, 2607:f8b0:4001:c16::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55956017 (53M) [application/zip]
# Saving to: ‘jigsaw-toxic-comment-classification-challenge.zip’
#
# jigsaw-toxic-commen 100%[===================>]  53.36M   103MB/s    in 0.5s
#
# 2019-05-17 16:10:47 (103 MB/s) - ‘jigsaw-toxic-comment-classification-challenge.zip’ saved [55956017/55956017]

# %%
# !ls
# Out:
# jigsaw-toxic-comment-classification-challenge.zip  sample_data

# %%
# !unzip jigsaw-toxic-comment-classification-challenge.zip
# Out:
# Archive:  jigsaw-toxic-comment-classification-challenge.zip
#   inflating: test_labels.csv
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv',encoding="ISO-8859-1")

# %%
df
# Out:
#                       id  ... identity_hate
# 0       0000997932d777bf  ...             0
# 1       000103f0d9cfb60f  ...             0
# 2       000113f07ec002fd  ...             0
# 3       0001b41b1c6bb37e  ...             0
# 4       0001d958c54c6e35  ...             0
# 5       00025465d4725e87  ...             0
# 6       0002bcb3da6cb337  ...             0
# 7       00031b1e95af7921  ...             0
# 8       00037261f536c51d  ...             0
# 9       00040093b2687caa  ...             0
# 10      0005300084f90edc  ...             0
# 11      00054a5e18b50dd4  ...             0
# 12      0005c987bdfc9d4b  ...             0
# 13      0006f16e4e9f292e  ...             0
# 14      00070ef96486d6f9  ...             0
# 15      00078f8ce7eb276d  ...             0
# 16      0007e25b2121310b  ...             0
# 17      000897889268bc93  ...             0
# 18      0009801bd85e5806  ...             0
# 19      0009eaea3325de8c  ...             0
# 20      000b08c464718505  ...             0
# 21      000bfd0867774845  ...             0
# 22      000c0dfd995809fa  ...             0
# 23      000c6a3f0cd3ba8e  ...             0
# 24      000cfee90f50d471  ...             0
# 25      000eefc67a2c930f  ...             0
# 26      000f35deef84dc4a  ...             0
# 27      000ffab30195c5e1  ...             0
# 28      0010307a3a50a353  ...             0
# 29      0010833a96e1f886  ...             0
# ...                  ...  ...           ...
# 159541  ffa33d3122b599d6  ...             0
# 159542  ffa95244f261527f  ...             0
# 159543  ffad104337fe9891  ...             0
# 159544  ffaed63c487a2b42  ...             0
# 159545  ffb268f37788a011  ...             0
# 159546  ffb47123b2d82762  ...             0
# 159547  ffb7b4c3d3ae5842  ...             0
# 159548  ffb93b0a0a1e78f9  ...             0
# 159549  ffb998f9749bd83e  ...             0
# 159550  ffba5332d6b8fd14  ...             0
# 159551  ffbc2db4225258dd  ...             0
# 159552  ffbcd64a71775e04  ...             0
# 159553  ffbd331a3aa269b9  ...             0
# 159554  ffbdbb0483ed0841  ...             0
# 159555  ffc2f409658571f1  ...             0
# 159556  ffc671f2acdd80e1  ...             0
# 159557  ffc7bbb177c3c966  ...             0
# 159558  ffca1e81aefc48ac  ...             0
# 159559  ffca8d71d71a3fae  ...             0
# 159560  ffcdcb71854f6d8a  ...             0
# 159561  ffd2e85b07b3c7e4  ...             0
# 159562  ffd72e9766c09c97  ...             0
# 159563  ffe029a7c79dc7fe  ...             0
# 159564  ffe897e7f7182c90  ...             0
# 159565  ffe8b9316245be30  ...             0
# 159566  ffe987279560d7ff  ...             0
# 159567  ffea4adeee384e90  ...             0
# 159568  ffee36eab5c267c9  ...             0
# 159569  fff125370e4aaaf3  ...             0
# 159570  fff46fc426af1f9a  ...             0
#
# [159571 rows x 8 columns]

# %%
df = df.drop(['id'] , axis = 1)

# %%
df
# Out:
#                                              comment_text  ...  identity_hate
# 0       Explanation\nWhy the edits made under my usern...  ...              0
# 1       D'aww! He matches this background colour I'm s...  ...              0
# 2       Hey man, I'm really not trying to edit war. It...  ...              0
# 3       "\nMore\nI can't make any real suggestions on ...  ...              0
# 4       You, sir, are my hero. Any chance you remember...  ...              0
# 5       "\n\nCongratulations from me as well, use the ...  ...              0
# 6            COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK  ...              0
# 7       Your vandalism to the Matt Shirvington article...  ...              0
# 8       Sorry if the word 'nonsense' was offensive to ...  ...              0
# 9       alignment on this subject and which are contra...  ...              0
# 10      "\nFair use rationale for Image:Wonju.jpg\n\nT...  ...              0
# 11      bbq \n\nbe a man and lets discuss it-maybe ove...  ...              0
# 12      Hey... what is it..\n@ | talk .\nWhat is it......  ...              0
# 13      Before you start throwing accusations and warn...  ...              0
# 14      Oh, and the girl above started her arguments w...  ...              0
# 15      "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...  ...              0
# 16      Bye! \n\nDon't look, come or think of comming ...  ...              0
# 17       REDIRECT Talk:Voydan Pop Georgiev- Chernodrinski  ...              0
# 18      The Mitsurugi point made no sense - why not ar...  ...              0
# 19      Don't mean to bother you \n\nI see that you're...  ...              0
# 20      "\n\n Regarding your recent edits \n\nOnce aga...  ...              0
# 21      "\nGood to know. About me, yeah, I'm studying ...  ...              0
# 22      "\n\n Snowflakes are NOT always symmetrical! \...  ...              0
# 23      "\n\n The Signpost: 24 September 2012 \n\n Rea...  ...              0
# 24      "\n\nRe-considering 1st paragraph edit?\nI don...  ...              0
# 25      Radial symmetry \n\nSeveral now extinct lineag...  ...              0
# 26      There's no need to apologize. A Wikipedia arti...  ...              0
# 27      Yes, because the mother of the child in the ca...  ...              0
# 28      "\nOk. But it will take a bit of work but I ca...  ...              0
# 29      "== A barnstar for you! ==\n\n  The Real Life ...  ...              0
# ...                                                   ...  ...            ...
# 159541  Your absurd edits \n\nYour absurd edits on gre...  ...              0
# 159542  maybe he's got better things to do than spend ...  ...              0
# 159543  scrap that, it does meet criteria and its gone...  ...              0
# 159544                                You could do worse.  ...              0
# 159545  , 7 March 2011 (UTC)\nAre you also User:Bmatts...  ...              0
# 159546  "\n\nHey listen don't you ever!!!! Delete my e...  ...              0
# 159547                  Thank you very, very much.  Â·â  ...              0
# 159548                        Talkback: 15 September 2012  ...              0
# 159549                         2005 (UTC)\n 06:35, 31 Mar  ...              0
# 159550  i agree/ on another note lil wayne is a talent...  ...              0
# 159551  While about half the references are from BYU-I...  ...              0
# 159552  Prague Spring \n\nI think that Prague Spring d...  ...              0
# 159553  I see this as having been merged; undoing one ...  ...              0
# 159554  and i'm going to keep posting the stuff u dele...  ...              0
# 159555  "\n\nHow come when you download that MP3 it's ...  ...              0
# 159556  I'll be on IRC, too, if you have a more specif...  ...              0
# 159557  It is my opinion that that happens to be off-t...  ...              0
# 159558  Please stop removing content from Wikipedia; i...  ...              0
# 159559  Image:Barack-obama-mother.jpg listed for delet...  ...              0
# 159560  "Editing of article without Consensus & Remova...  ...              0
# 159561  "\nNo he did not, read it again (I would have ...  ...              0
# 159562  "\n Auto guides and the motoring press are not...  ...              0
# 159563  "\nplease identify what part of BLP applies be...  ...              0
# 159564  Catalan independentism is the social movement ...  ...              0
# 159565  The numbers in parentheses are the additional ...  ...              0
# 159566  ":::::And for the second time of asking, when ...  ...              0
# 159567  You should be ashamed of yourself \n\nThat is ...  ...              0
# 159568  Spitzer \n\nUmm, theres no actual article for ...  ...              0
# 159569  And it looks like it was actually you who put ...  ...              0
# 159570  "\nAnd ... I really don't think you understand...  ...              0
#
# [159571 rows x 7 columns]

# %%
import torch.utils.data
import sklearn.metrics
import torch
import pandas as pd
from torch.utils.data import Dataset
import tqdm
import spacy
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
import fastai
from keras.preprocessing import text,sequence

# %%
from fastai.train import Learner
from fastai.train import DataBunch

# %%
df['comment_text'] = df['comment_text'].fillna('no data is present')
df['toxic'] = df['toxic'].fillna('0')
df['severe_toxic'] = df['severe_toxic'].fillna('0')
df['obscene'] = df['obscene'].fillna('0')
df['threat'] = df['threat'].fillna('0')
df['insult'] = df['insult'].fillna('0')
df['identity_hate'] = df['identity_hate'].fillna('0')

# %%
df
# Out:
#                                              comment_text  ...  identity_hate
# 0       Explanation\nWhy the edits made under my usern...  ...              0
# 1       D'aww! He matches this background colour I'm s...  ...              0
# 2       Hey man, I'm really not trying to edit war. It...  ...              0
# 3       "\nMore\nI can't make any real suggestions on ...  ...              0
# 4       You, sir, are my hero. Any chance you remember...  ...              0
# 5       "\n\nCongratulations from me as well, use the ...  ...              0
# 6            COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK  ...              0
# 7       Your vandalism to the Matt Shirvington article...  ...              0
# 8       Sorry if the word 'nonsense' was offensive to ...  ...              0
# 9       alignment on this subject and which are contra...  ...              0
# 10      "\nFair use rationale for Image:Wonju.jpg\n\nT...  ...              0
# 11      bbq \n\nbe a man and lets discuss it-maybe ove...  ...              0
# 12      Hey... what is it..\n@ | talk .\nWhat is it......  ...              0
# 13      Before you start throwing accusations and warn...  ...              0
# 14      Oh, and the girl above started her arguments w...  ...              0
# 15      "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...  ...              0
# 16      Bye! \n\nDon't look, come or think of comming ...  ...              0
# 17       REDIRECT Talk:Voydan Pop Georgiev- Chernodrinski  ...              0
# 18      The Mitsurugi point made no sense - why not ar...  ...              0
# 19      Don't mean to bother you \n\nI see that you're...  ...              0
# 20      "\n\n Regarding your recent edits \n\nOnce aga...  ...              0
# 21      "\nGood to know. About me, yeah, I'm studying ...  ...              0
# 22      "\n\n Snowflakes are NOT always symmetrical! \...  ...              0
# 23      "\n\n The Signpost: 24 September 2012 \n\n Rea...  ...              0
# 24      "\n\nRe-considering 1st paragraph edit?\nI don...  ...              0
# 25      Radial symmetry \n\nSeveral now extinct lineag...  ...              0
# 26      There's no need to apologize. A Wikipedia arti...  ...              0
# 27      Yes, because the mother of the child in the ca...  ...              0
# 28      "\nOk. But it will take a bit of work but I ca...  ...              0
# 29      "== A barnstar for you! ==\n\n  The Real Life ...  ...              0
# ...                                                   ...  ...            ...
# 159541  Your absurd edits \n\nYour absurd edits on gre...  ...              0
# 159542  maybe he's got better things to do than spend ...  ...              0
# 159543  scrap that, it does meet criteria and its gone...  ...              0
# 159544                                You could do worse.  ...              0
# 159545  , 7 March 2011 (UTC)\nAre you also User:Bmatts...  ...              0
# 159546  "\n\nHey listen don't you ever!!!! Delete my e...  ...              0
# 159547                  Thank you very, very much.  Â·â  ...              0
# 159548                        Talkback: 15 September 2012  ...              0
# 159549                         2005 (UTC)\n 06:35, 31 Mar  ...              0
# 159550  i agree/ on another note lil wayne is a talent...  ...              0
# 159551  While about half the references are from BYU-I...  ...              0
# 159552  Prague Spring \n\nI think that Prague Spring d...  ...              0
# 159553  I see this as having been merged; undoing one ...  ...              0
# 159554  and i'm going to keep posting the stuff u dele...  ...              0
# 159555  "\n\nHow come when you download that MP3 it's ...  ...              0
# 159556  I'll be on IRC, too, if you have a more specif...  ...              0
# 159557  It is my opinion that that happens to be off-t...  ...              0
# 159558  Please stop removing content from Wikipedia; i...  ...              0
# 159559  Image:Barack-obama-mother.jpg listed for delet...  ...              0
# 159560  "Editing of article without Consensus & Remova...  ...              0
# 159561  "\nNo he did not, read it again (I would have ...  ...              0
# 159562  "\n Auto guides and the motoring press are not...  ...              0
# 159563  "\nplease identify what part of BLP applies be...  ...              0
# 159564  Catalan independentism is the social movement ...  ...              0
# 159565  The numbers in parentheses are the additional ...  ...              0
# 159566  ":::::And for the second time of asking, when ...  ...              0
# 159567  You should be ashamed of yourself \n\nThat is ...  ...              0
# 159568  Spitzer \n\nUmm, theres no actual article for ...  ...              0
# 159569  And it looks like it was actually you who put ...  ...              0
# 159570  "\nAnd ... I really don't think you understand...  ...              0
#
# [159571 rows x 7 columns]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
exceptionStopWords = {
    'again',
    'against',
    'ain',
    'almost',
    'among',
    'amongst',
    'amount',
    'anyhow',
    'anyway',
    'aren',
    "aren't",
    'below',
    'bottom',
    'but',
    'cannot',
    'couldn',
    "couldn't",
    'didn',
    "didn't",
    'doesn',
    "doesn't",
    'don',
    "don't",
    'done',
    'down',
    'except',
    'few',
    'hadn',
    "hadn't",
    'hasn',
    "hasn't",
    'haven',
    "haven't",
    'however',
    'isn',
    "isn't",
    'least',
    'mightn',
    "mightn't",
    'move',
    'much',
    'must',
    'mustn',
    "mustn't",
    'needn',
    "needn't",
    'neither',
    'never',
    'nevertheless',
    'no',
    'nobody',
    'none',
    'noone',
    'nor',
    'not',
    'nothing',
    'should',
    "should've",
    'shouldn',
    "shouldn't",
    'too',
    'top',
    'up',
    'very'
    'wasn',
    "wasn't",
    'well',
    'weren',
    "weren't",
    'won',
    "won't",
    'wouldn',
    "wouldn't",
}

# %%
stop_words = set(stop_words).union(STOP_WORDS)

# %%
final_stop_words = stop_words-exceptionStopWords

# %%
final_stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'all',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyone',
#  'anything',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'could',
#  'd',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'having',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'less',
#  'll',
#  'm',
#  'ma',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'my',
#  'myself',
#  'name',
#  'namely',
#  'next',
#  'nine',
#  'now',
#  'nowhere',
#  'o',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  's',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  't',
#  'take',
#  'ten',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  've',
#  'very',
#  'via',
#  'was',
#  'wasn',
#  'we',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'y',
#  'yet',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
CONTRACTION_MAP = {"ain't": "is not", "aren't": "are not","can't": "cannot", 
                   "can't've": "cannot have", "'cause": "because", "could've": "could have", 
                   "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
                   "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
                   "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
                   "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
                   "he'll've": "he he will have", "he's": "he is", "how'd": "how did", 
                   "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
                   "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
                   "I'll've": "I will have","I'm": "I am", "I've": "I have", 
                   "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
                   "i'll've": "i will have","i'm": "i am", "i've": "i have", 
                   "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
                   "it'll": "it will", "it'll've": "it will have","it's": "it is", 
                   "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
                   "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
                   "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
                   "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have" }

# %%
def expand_contractions(sentence, contraction_mapping): 
     
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),  
                                      flags=re.IGNORECASE|re.DOTALL) 
    def expand_match(contraction): 
        match = contraction.group(0) 
        first_char = match[0] 
        expanded_contraction = contraction_mapping.get(match) if contraction_mapping.get(match) else contraction_mapping.get(match.lower())                        
        expanded_contraction = first_char+expanded_contraction[1:] 
        return expanded_contraction 
         
    expanded_sentence = contractions_pattern.sub(expand_match, sentence) 
    return expanded_sentence

# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import gensim
import re
from nltk.stem import PorterStemmer
ps = PorterStemmer()
from nltk.stem.lancaster import LancasterStemmer
lc = LancasterStemmer()
from nltk.stem import SnowballStemmer
sb = SnowballStemmer("english")

# %%
l = []

for row,index in tqdm.tqdm(df.iterrows()):
    #print(l[i])
    s = [expand_contractions(txt, CONTRACTION_MAP)  
                     for txt in sent_tokenize(index[0])]
    
    #print(s)
    #print(l[i])
    
    res = []
    sample = ' '.join(s)
    sample = sample.split()
    #print(sample)
    for j in sample:
      if j not in final_stop_words:
        res.append(j)
    #break
    l.append(' '.join(res))    
    #print(l)
    #break
# Out:
# 159571it [02:48, 944.84it/s]

# %%
res = []
for text in l:
  punct = "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~`" + '"“”’=' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&'+'\n'
  for p in punct:
    text = text.replace(p, ' ')
  res.append(text)

# %%
preprocessed_data = pd.DataFrame(res)

# %%
preprocessed_data[0]
# Out:
# 0         Explanation Why edits username Hardcore Metall...
# 1         D aww  He matches background colour I seemingl...
# 2         Hey man  I not trying edit war  It guy constan...
# 3           More I cannot real suggestions improvement  ...
# 4              You  sir  hero  Any chance remember page on
# 5           Congratulations well  use tools well  Â Â· t...
# 6              COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 7         Your vandalism Matt Shirvington article revert...
# 8         Sorry word  nonsense  offensive you  Anyway  I...
# 9                      alignment subject contrary DuLithgow
# 10          Fair use rationale Image Wonju jpg Thanks up...
# 11                     bbq man lets discuss it maybe phone
# 12        Hey    it       talk   What it    exclusive gr...
# 13        Before start throwing accusations warnings me ...
# 14        Oh  girl started arguments me  She stuck nose ...
# 15          Juelz Santanas Age In 2002  Juelz Santana 18...
# 16        Bye  Do not look  come think comming back  Tos...
# 17         REDIRECT Talk Voydan Pop Georgiev  Chernodrinski
# 18        The Mitsurugi point no sense   not argue inclu...
# 19        Do not mean bother I writing removing posted o...
# 20          Regarding recent edits Once again  read WP F...
# 21          Good know  About me  yeah  I studying now   ...
# 22          Snowflakes NOT symmetrical  Under Geometry s...
# 23          The Signpost  24 September 2012 Read Signpos...
# 24          Re considering 1st paragraph edit  I not und...
# 25        Radial symmetry Several extinct lineages inclu...
# 26        There no need apologize  A Wikipedia article r...
# 27        Yes  mother child case against Michael Jackson...
# 28          Ok  But bit work but I cannot picture it  Do...
# 29            A barnstar you     The Real Life Barnstar ...
#                                 ...
# 159541    Your absurd edits Your absurd edits great whit...
# 159542    maybe got better things spend day  day wikiped...
# 159543    scrap that  meet criteria gone deletion review...
# 159544                                           You worse
# 159545      7 March 2011  UTC  Are User Bmattson  What w...
# 159546      Hey listen not ever     Delete edits again I...
# 159547                              Thank very  much  Â·â
# 159548                          Talkback  15 September 2012
# 159549                             2005  UTC  06 35  31 Mar
# 159550    agree  note lil wayne talentless man  If tupac...
# 159551    While half references BYU I  majority comes in...
# 159552    Prague Spring I think Prague Spring deserves s...
# 159553    I merged  undoing merge forks content large bl...
# 159554    going posting stuff u deleted fucking site clo...
# 159555      How come download MP3 titled   odb    That O...
# 159556                        I IRC  too  specific request
# 159557    It opinion happens off topic  I believe I neve...
# 159558    Please stop removing content Wikipedia  consid...
# 159559    Image Barack obama mother jpg listed deletion ...
# 159560     Editing article Consensus   Removal Cited Con...
# 159561      No not  read again  I thought recite heart n...
# 159562      Auto guides motoring press not good sources ...
# 159563      identify BLP applies BLP clearly states must...
# 159564    Catalan independentism social movement involvi...
# 159565    The numbers parentheses additional decimal poi...
# 159566          And second time asking  view completely ...
# 159567    You should ashamed That horrible thing talk pa...
# 159568    Spitzer Umm  theres no actual article prostitu...
# 159569    And looks like actually speedy version deleted...
# 159570      And     I not think understand  I came idea ...
# Name: 0, Length: 159571, dtype: object

# %%
arr = df.columns

classes = arr[1:]
classes = np.asarray(classes)
classes = classes.tolist()
#classes

#df = make_data(df)

# %%
df.columns
# Out:
# Index(['comment_text', 'toxic', 'severe_toxic', 'obscene', 'threat', 'insult',
#        'identity_hate'],
#       dtype='object')

# %%
def make_data(df):
  data=[]
  lab=[]
  for row,index in df.iterrows():
    temp=[]
    for class_name in classes:
      if index[class_name]==1:
        temp.append(class_name)
      if len(temp)==0: 
        temp.append("no_class")
    temp = ' '.join(temp)
    lab.append(temp)
    data.append(index["comment_text"])
  X = pd.DataFrame({"labels":lab,"text":data})
  return X

# %%
classes
# Out:
# ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

# %%
df = make_data(df)

# %%
df
# Out:
#                                    labels                                               text
# 0                                no_class  Explanation\nWhy the edits made under my usern...
# 1                                no_class  D'aww! He matches this background colour I'm s...
# 2                                no_class  Hey man, I'm really not trying to edit war. It...
# 3                                no_class  "\nMore\nI can't make any real suggestions on ...
# 4                                no_class  You, sir, are my hero. Any chance you remember...
# 5                                no_class  "\n\nCongratulations from me as well, use the ...
# 6       toxic severe_toxic obscene insult       COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 7                                no_class  Your vandalism to the Matt Shirvington article...
# 8                                no_class  Sorry if the word 'nonsense' was offensive to ...
# 9                                no_class  alignment on this subject and which are contra...
# 10                               no_class  "\nFair use rationale for Image:Wonju.jpg\n\nT...
# 11                               no_class  bbq \n\nbe a man and lets discuss it-maybe ove...
# 12                                  toxic  Hey... what is it..\n@ | talk .\nWhat is it......
# 13                               no_class  Before you start throwing accusations and warn...
# 14                               no_class  Oh, and the girl above started her arguments w...
# 15                               no_class  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 16                                  toxic  Bye! \n\nDon't look, come or think of comming ...
# 17                               no_class   REDIRECT Talk:Voydan Pop Georgiev- Chernodrinski
# 18                               no_class  The Mitsurugi point made no sense - why not ar...
# 19                               no_class  Don't mean to bother you \n\nI see that you're...
# 20                               no_class  "\n\n Regarding your recent edits \n\nOnce aga...
# 21                               no_class  "\nGood to know. About me, yeah, I'm studying ...
# 22                               no_class  "\n\n Snowflakes are NOT always symmetrical! \...
# 23                               no_class  "\n\n The Signpost: 24 September 2012 \n\n Rea...
# 24                               no_class  "\n\nRe-considering 1st paragraph edit?\nI don...
# 25                               no_class  Radial symmetry \n\nSeveral now extinct lineag...
# 26                               no_class  There's no need to apologize. A Wikipedia arti...
# 27                               no_class  Yes, because the mother of the child in the ca...
# 28                               no_class  "\nOk. But it will take a bit of work but I ca...
# 29                               no_class  "== A barnstar for you! ==\n\n  The Real Life ...
# ...                                   ...                                                ...
# 159541               toxic obscene insult  Your absurd edits \n\nYour absurd edits on gre...
# 159542                           no_class  maybe he's got better things to do than spend ...
# 159543                           no_class  scrap that, it does meet criteria and its gone...
# 159544                           no_class                                You could do worse.
# 159545                           no_class  , 7 March 2011 (UTC)\nAre you also User:Bmatts...
# 159546                       toxic insult  "\n\nHey listen don't you ever!!!! Delete my e...
# 159547                           no_class                  Thank you very, very much.  Â·â
# 159548                           no_class                        Talkback: 15 September 2012
# 159549                           no_class                         2005 (UTC)\n 06:35, 31 Mar
# 159550                           no_class  i agree/ on another note lil wayne is a talent...
# 159551                           no_class  While about half the references are from BYU-I...
# 159552                           no_class  Prague Spring \n\nI think that Prague Spring d...
# 159553                           no_class  I see this as having been merged; undoing one ...
# 159554               toxic obscene insult  and i'm going to keep posting the stuff u dele...
# 159555                           no_class  "\n\nHow come when you download that MP3 it's ...
# 159556                           no_class  I'll be on IRC, too, if you have a more specif...
# 159557                           no_class  It is my opinion that that happens to be off-t...
# 159558                           no_class  Please stop removing content from Wikipedia; i...
# 159559                           no_class  Image:Barack-obama-mother.jpg listed for delet...
# 159560                           no_class  "Editing of article without Consensus & Remova...
# 159561                           no_class  "\nNo he did not, read it again (I would have ...
# 159562                           no_class  "\n Auto guides and the motoring press are not...
# 159563                           no_class  "\nplease identify what part of BLP applies be...
# 159564                           no_class  Catalan independentism is the social movement ...
# 159565                           no_class  The numbers in parentheses are the additional ...
# 159566                           no_class  ":::::And for the second time of asking, when ...
# 159567                           no_class  You should be ashamed of yourself \n\nThat is ...
# 159568                           no_class  Spitzer \n\nUmm, theres no actual article for ...
# 159569                           no_class  And it looks like it was actually you who put ...
# 159570                           no_class  "\nAnd ... I really don't think you understand...
#
# [159571 rows x 2 columns]

# %%
df['text'] = preprocessed_data[0]

# %%
df
# Out:
#                                    labels                                               text
# 0                                no_class  Explanation Why edits username Hardcore Metall...
# 1                                no_class  D aww  He matches background colour I seemingl...
# 2                                no_class  Hey man  I not trying edit war  It guy constan...
# 3                                no_class    More I cannot real suggestions improvement  ...
# 4                                no_class       You  sir  hero  Any chance remember page on
# 5                                no_class    Congratulations well  use tools well  Â Â· t...
# 6       toxic severe_toxic obscene insult       COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 7                                no_class  Your vandalism Matt Shirvington article revert...
# 8                                no_class  Sorry word  nonsense  offensive you  Anyway  I...
# 9                                no_class               alignment subject contrary DuLithgow
# 10                               no_class    Fair use rationale Image Wonju jpg Thanks up...
# 11                               no_class               bbq man lets discuss it maybe phone
# 12                                  toxic  Hey    it       talk   What it    exclusive gr...
# 13                               no_class  Before start throwing accusations warnings me ...
# 14                               no_class  Oh  girl started arguments me  She stuck nose ...
# 15                               no_class    Juelz Santanas Age In 2002  Juelz Santana 18...
# 16                                  toxic  Bye  Do not look  come think comming back  Tos...
# 17                               no_class   REDIRECT Talk Voydan Pop Georgiev  Chernodrinski
# 18                               no_class  The Mitsurugi point no sense   not argue inclu...
# 19                               no_class  Do not mean bother I writing removing posted o...
# 20                               no_class    Regarding recent edits Once again  read WP F...
# 21                               no_class    Good know  About me  yeah  I studying now   ...
# 22                               no_class    Snowflakes NOT symmetrical  Under Geometry s...
# 23                               no_class    The Signpost  24 September 2012 Read Signpos...
# 24                               no_class    Re considering 1st paragraph edit  I not und...
# 25                               no_class  Radial symmetry Several extinct lineages inclu...
# 26                               no_class  There no need apologize  A Wikipedia article r...
# 27                               no_class  Yes  mother child case against Michael Jackson...
# 28                               no_class    Ok  But bit work but I cannot picture it  Do...
# 29                               no_class      A barnstar you     The Real Life Barnstar ...
# ...                                   ...                                                ...
# 159541               toxic obscene insult  Your absurd edits Your absurd edits great whit...
# 159542                           no_class  maybe got better things spend day  day wikiped...
# 159543                           no_class  scrap that  meet criteria gone deletion review...
# 159544                           no_class                                         You worse
# 159545                           no_class    7 March 2011  UTC  Are User Bmattson  What w...
# 159546                       toxic insult    Hey listen not ever     Delete edits again I...
# 159547                           no_class                            Thank very  much  Â·â
# 159548                           no_class                        Talkback  15 September 2012
# 159549                           no_class                           2005  UTC  06 35  31 Mar
# 159550                           no_class  agree  note lil wayne talentless man  If tupac...
# 159551                           no_class  While half references BYU I  majority comes in...
# 159552                           no_class  Prague Spring I think Prague Spring deserves s...
# 159553                           no_class  I merged  undoing merge forks content large bl...
# 159554               toxic obscene insult  going posting stuff u deleted fucking site clo...
# 159555                           no_class    How come download MP3 titled   odb    That O...
# 159556                           no_class                      I IRC  too  specific request
# 159557                           no_class  It opinion happens off topic  I believe I neve...
# 159558                           no_class  Please stop removing content Wikipedia  consid...
# 159559                           no_class  Image Barack obama mother jpg listed deletion ...
# 159560                           no_class   Editing article Consensus   Removal Cited Con...
# 159561                           no_class    No not  read again  I thought recite heart n...
# 159562                           no_class    Auto guides motoring press not good sources ...
# 159563                           no_class    identify BLP applies BLP clearly states must...
# 159564                           no_class  Catalan independentism social movement involvi...
# 159565                           no_class  The numbers parentheses additional decimal poi...
# 159566                           no_class        And second time asking  view completely ...
# 159567                           no_class  You should ashamed That horrible thing talk pa...
# 159568                           no_class  Spitzer Umm  theres no actual article prostitu...
# 159569                           no_class  And looks like actually speedy version deleted...
# 159570                           no_class    And     I not think understand  I came idea ...
#
# [159571 rows x 2 columns]

# %%
# !rm -r clean_train.csv

# %%
# !ls
# Out:
# jigsaw-toxic-comment-classification-challenge.zip  test.csv
# sample_data					   test_labels.csv
# sample_submission.csv				   train.csv

# %%
df.to_csv('clean_train.csv')

# %%
x = pd.read_csv('clean_train.csv')

# %%
x.loc[x.isnull().any(axis=1)]
# Out:
#        Unnamed: 0    labels text
# 25050       25050  no_class  NaN
# 43642       43642  no_class  NaN
# 62881       62881  no_class  NaN
# 71168       71168  no_class  NaN

# %%
from fastai.text import *
path = '.'
data_lm = TextDataBunch.from_df(path, train_df = df[:140000], valid_df = df[140000:], text_cols=1,max_vocab=60000,min_freq=2, label_cols=0,label_delim=" ")

# %%
text_data = []
for i in data_lm.x:
  text_data.append(i.plit())
  print(i)
  break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-186-c8518e157257> in <module>()
#       1 text_data = []
#       2 for i in data_lm.x:
# ----> 3   text_data.append(i.astype(str).split())
#       4   print(i)
#       5   break
#
# AttributeError: 'Text' object has no attribute 'astype'

# %%
text_data
# Out:
# [Text xxbos xxmaj explanation xxmaj why edits username xxmaj hardcore xxmaj metallica xxmaj fan reverted xxmaj they not vandalisms closure gas i voted xxmaj new xxmaj york xxmaj dolls xxup fac xxmaj and not remove template talk page i retired now 89 205 38 27,
#  Text xxbos d aww xxmaj he matches background colour i seemingly stuck with xxmaj thanks talk 21 51 xxmaj january 11 2016 xxup utc,
#  Text xxbos xxmaj hey man i not trying edit war xxmaj it guy constantly removing relevant information talking edits instead talk page xxmaj he care formatting actual info,
#  Text xxbos xxmaj more i can not real suggestions improvement i wondered section statistics should later on subsection types accidents i think references need tidying exact format ie date format etc i later on no one preferences formatting style references want let know xxmaj there appears backlog articles review i guess delay reviewer turns up xxmaj it listed relevant form eg xxmaj wikipedia xxmaj good article nominations xxmaj transport,
#  Text xxbos xxmaj you sir hero xxmaj any chance remember page on,
#  Text xxbos xxmaj congratulations well use tools well â â · talk,
#  Text xxbos xxup cocksucker xxup before xxup you xxup piss xxup around xxup on xxup my xxup work,
#  Text xxbos xxmaj your vandalism xxmaj matt xxmaj xxunk article reverted xxmaj please not again banned,
#  Text xxbos xxmaj sorry word nonsense offensive you xxmaj anyway i not intending write article wow jump vandalism i merely requesting encyclopedic use school reference i selective breeding page but almost stub xxmaj it points animal breeding short messy article gives no info xxmaj there must expertise eugenics 93 161 107 169,
#  Text xxbos alignment subject contrary dulithgow,
#  Text xxbos xxmaj fair use rationale xxmaj image xxmaj wonju jpg xxmaj thanks uploading xxmaj image xxmaj wonju jpg i notice image page specifies image fair use but no explanation rationale use xxmaj wikipedia articles constitutes fair use xxmaj in addition boilerplate fair use template must write image description page specific explanation rationale image article consistent fair use xxmaj please image description page edit include fair use rationale xxmaj if uploaded fair use media consider checking specified fair use rationale pages too xxmaj you find list image pages edited clicking my contributions link it located top xxmaj wikipedia page logged in selecting xxmaj image dropdown box xxmaj note fair use images uploaded 4 xxmaj may 2006 lacking explanation deleted week uploaded described criteria speedy deletion xxmaj if questions ask xxmaj media copyright questions page xxmaj thank you talk â¢ contribs â¢ xxmaj unspecified source xxmaj image xxmaj wonju jpg xxmaj thanks uploading xxmaj image xxmaj wonju jpg i noticed file s description page currently not specify created content copyright status unclear xxmaj if not create file yourself need specify owner copyright xxmaj if obtained website link website taken restatement website s terms use content usually sufficient information xxmaj however copyright holder different website s publisher copyright should acknowledged xxmaj as well adding source add proper copyright licensing tag file not already xxmaj if created took picture audio video tag release xxup gfdl xxmaj if believe media meets criteria xxmaj wikipedia xxmaj fair use use tag tags listed xxmaj wikipedia xxmaj image copyright tags xxmaj fair use xxmaj see xxmaj wikipedia xxmaj image copyright tags list copyright tags use xxmaj if uploaded files consider checking specified source tagged them too xxmaj you find list files uploaded following link xxmaj unsourced untagged images deleted week tagged described criteria speedy deletion xxmaj if image copyrighted non free license per xxmaj wikipedia xxmaj fair use image deleted 48 hours xxmaj if questions ask xxmaj media copyright questions page xxmaj thank you talk â¢ contribs â¢,
#  Text xxbos xxmaj thanks much however resolved today i not write edit summary xxup camera ad edit summary box xxunk talk,
#  Text xxbos xxmaj you right but username able impact i saying xxmaj and familiar probably username xxmaj just one takes 10 seconds talkâ¢contribs,
#  Text xxbos xxmaj however xxmaj xxunk edit noted golden xxunk on optus xxmaj wake up xxunk xxmaj so funny,
#  Text xxbos xxmaj check following websites http www iranchamber com personalities farabi farabi php http www islam org br xxup c2 xxmaj xxunk farabi htm http www xxunk com sohbet sohbet htm,
#  Text xxbos can not believe no up page xxmaj dilbert s xxmaj desktop xxmaj games i,
#  Text xxbos xxmaj well i asked provide diffs hour edit here edit talk page not provide diffs i requested hour edit i sanctioned failing provide requested diffs timely manner which week not done xxmaj consequently request lift sanction denied,
#  Text xxbos xxmaj what page shoudld important characters xxmaj do not reoccur xxmaj void xxmaj black xxmaj doom xxmaj xxunk etc,
#  Text xxbos a pair jew hating weiner nazi schmucks,
#  Text xxbos i tend think list longer rest article problem xxmaj either history characteristics should expanded list should culled i personally like consensus reached xxmaj xxunk article others myself included xxmaj we decided country origin should highlighted examples xxmaj there xxmaj trappist xxmaj abbey xxmaj foreign xxmaj foreign includes non xxmaj belgium examples xxmaj this way article article encyclopedia not list xxmaj people find lists anywhere article should reference this xxmaj also style statistics bad xxmaj when style statistics sounds like prescription not description xxmaj an encyclopedia should follow latter used citation should follow xxmaj and not find valid style country origin,
#  Text xxbos xxmaj what up this xxmaj if religiously politically motivated push issue refrain talking page i not interested xxmaj otherwise feel free talk relevant edits science xxmaj deleet talk i prefer following users never post here xxmaj maunus xxunk weijibaikebianji xxmaj this guy published psychology researcher right xxmaj perhaps not know access libraries best sources xxmaj you should point often xxmaj it not come mind xxunk condescending xxmaj also i suspect editor racist xxmaj see wiki 121 134 219 36,
#  Text xxbos i not vandalizing i fun man no sense humor think i vandalizing stuff lemonparty org this site,
#  Text xxbos xxmaj welcome xxmaj wikipedia bla xxmaj discover xxmaj ekopedia practical encyclopedia alternative life techniques bla xxmaj discover xxmaj ekopedia practical encyclopedia alternative life techniques,
#  Text xxbos xxmaj including appropriate mention xxmaj solomon article not level support,
#  Text xxbos xxmaj comment i not verify claim talk,
#  Text xxbos xxmaj czech xxmaj republic xxmaj central xxmaj europe xxmaj the state article reason people making confusions xxmaj especially ridiculous replace mention xxmaj north xxmaj caucasus favor north slope xxmaj caucasus xxmaj mountains is nt geographical area denoting mountains region xxmaj countries located continents reason refuse allow article denoted continent xxmaj this single factor massive difference readers i tired arguing people essentially wiki squatters refusing nudge given article 24 90 230 216,
#  Text xxbos xxmaj thanks xxmaj josette i enjoyed meeting you too i shocked decision not begin reflect consensus xxmaj does xxmaj grand xxmaj poobah alone xxmaj serves right stealing time pressing real world duties indulge fun hobby i learned lesson not waste time like again i stick fixing little things i run i read articles information,
#  Text xxbos xxmaj paleontologists agree organic remains must buried quickly preserved long come fossilized xxmaj however term fossilized not precise term xxmaj there factors metamorphic mineral processes occur organic remains result typically called fossil xxmaj one major factor concerns kind organisms fossilized vertebrate xxunk xxunk sponges plants pollen foot prints etc xxmaj and multiple processes include permineralization xxunk carbonization replacement dissolving xxunk etc xxmaj talking fossilization complex issue however quick burial not questioned xxmaj the major question is long processes work organic reamins environment found in xxmaj experimental taphonomy resulted assortment remains fossilized processes lab course implies given right conditions vast ages not issue xxmaj the metamorphic processes ongoing equilibrium met chemical xxunk burial site minerals organic remains xxmaj flood catastrophic geologists not expect organic remains buried flood completely fossilized year period flood but 4000 years processes working xxmaj much work needs done taphonomy organic remains xxmaj yet interprets results depend world view choose believe with,
#  Text xxbos xxmaj also i think xxmaj vegetable xxmaj basket needs xxmaj wikipedia page,
#  Text xxbos xxmaj bigfoot xxmaj reference xxmaj the magazine better known xxmaj engineering xxmaj mining xxmaj journal difficult time finding depending live i ran article few years ago researching else copy xxmaj it clearly derived press accounts treats incident joke xxmaj my point citing incident was not entirely created 40 years fact xxmaj if leave email i scan page email xxup pdf,
#  Text xxbos xxmaj also ca nt trust xxmaj xxunk xxmaj xxunk http books google com books i d xxunk pg xxup xxunk dq xxmaj thiyya matrilineal hl en sa x ei xxunk ved xxunk v onepage q xxmaj thiyya 20matrilineal f false,
#  Text xxbos xxmaj chart performance xxmaj single xxmaj ladies xxmaj put xxmaj ring xxmaj it xxmaj please advice split up paragraphs section fas generally short paragraphs xxmaj it hard boring ingest much information once splitting paragraphs improve flow â â · xxup talk,
#  Text xxbos hahahaha good i removed it,
#  Text xxbos xxmaj having said that i temporarily removed requests based xxmaj cyde s advice pending request consensus asked talk page i urge reading vote know community wants,
#  Text xxbos xxmaj conformity healthy i missed it but article not address conformity healthy behaviour xxmaj such way conform grammar understood conform laws recognise need orderly society 194 126 85 214,
#  Text xxbos xxmaj hi i new wikipedia xxmaj read up xxunk today i impressed quality information knowledge not easily available easily accessible format xxmaj thank creating content making accessible,
#  Text xxbos xxmaj should views educationalist socialist political commentator xxmaj link http www xxunk xxunk ca xxmaj xxunk xxunk html mentions bit stood election candidate xxmaj respect,
#  Text xxbos xxmaj sandbox xxmaj do not template sandbox xxmaj it says do not remove reason 11 36 10 xxmaj jan 2005 xxup utc,
#  Text xxbos heh bit copy xxmaj wikipedia wikiproject xxmaj professional wrestling but i thought look bit tidy better way,
#  Text xxbos xxmaj ahh xxmaj hello xxmaj witzeman 203 92 84 161 xxmaj symbols â ¡ â ¿ â â ¡ xxunk â â â¢ xxup â¶ xxup â½ â  â  xxup xxunk xxup â¾ â  â  â  â  â â â â â xxup â«â » xxup â¤ â ¸ ¿ xxunk xxup â¢ â ¡ xxunk â « xxunk â¬ â â xxup æ â xxunk xxunk xxunk xxunk â ¦ â xxunk â â xxunk xxunk âª § â ® â © xxup â¥ â â â¥ â ¦ mâ mâ xxmaj characters xxup ã ã ¡ xxup ä xxup xxunk xxup xxunk ã © xxup xxunk xxup ã­ xxup xxunk xxmaj xxunk xxup xxunk xxup å xxup ã ã xxup xxunk xxup xxunk xxup xxunk xxup å xxup ã xxmaj xxunk xxup xxunk xxup xxunk xxup å¹ xxmaj åº xxup xxunk ã xxup xxunk xxup ã¨ xxup xxunk xxup ã¬ xxup xxunk ã xxup xxunk xxup xxunk xxup ã xxup xxunk xxup xxunk xxup xxunk xxup xxunk x
#  Text xxbos 12 xxmaj april 2006 xxup utc xxmaj then rewrite expand article i much article bad article template xxmaj as xxmaj william s edits i not going vote content matter time i never looked article sent link i not equipped choose version another xxmaj my vote purely layout aesthetics including template xxmaj maybe later i spent time unfamiliar article i statement content 16 06,
#  Text xxbos i trying inject humour as evidenced winky face ridiculous overblown unnecessarily dramatic situation xxmaj if took time familiarize situation person i insulted attacking cited factual contributions actively censoring no explanation i retaliated insulting him i thought conduct insult worthy time sane individual not familiar xxmaj wikipedia s no insult rule however i realized i wrong site not allow harsh words i not use again against me ordeal xxmaj wikipedia place edit constructive brought greater knowledge subject s topic xxmaj but fact i insulted user edit summary regrettable i know now xxmaj if seriously think edit linked constitutes better insult,
#  Text xxbos title should redirect xxmaj xxunk xxmaj hamburg i w d change but moment too links bother,
#  ...]

# %%
learn = text_classifier_learner(data_lm, drop_mult=0.5, arch=AWD_LSTM, metrics=accuracy_thresh)
#learn.load_encoder('fine_tuned_enc')
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1, 2e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.159151</td>
#       <td>0.162936</td>
#       <td>0.954816</td>
#       <td>04:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(text_data,size=100, window=4, min_count=0, workers=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-e067d9c3dfed> in <module>()
# ----> 1 model = Word2Vec(text_data,size=100, window=4, min_count=0, workers=4)
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, max_final_vocab)
#     765             callbacks=callbacks, batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window,
#     766             seed=seed, hs=hs, negative=negative, cbow_mean=cbow_mean, min_alpha=min_alpha, compute_loss=compute_loss,
# --> 767             fast_version=FAST_VERSION)
#     768
#     769     def _do_train_epoch(self, corpus_file, thread_id, offset, cython_vocab, thread_private_mem, cur_epoch,
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/base_any2vec.py in __init__(self, sentences, corpus_file, workers, vector_size, epochs, callbacks, batch_words, trim_rule, sg, alpha, window, seed, hs, negative, ns_exponent, cbow_mean, min_alpha, compute_loss, fast_version, **kwargs)
#     757                 raise TypeError("You can't pass a generator as the sentences argument. Try an iterator.")
#     758
# --> 759             self.build_vocab(sentences=sentences, corpus_file=corpus_file, trim_rule=trim_rule)
#     760             self.train(
#     761                 sentences=sentences, corpus_file=corpus_file, total_examples=self.corpus_count,
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/base_any2vec.py in build_vocab(self, sentences, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     934         """
#     935         total_words, corpus_count = self.vocabulary.scan_vocab(
# --> 936             sentences=sentences, corpus_file=corpus_file, progress_per=progress_per, trim_rule=trim_rule)
#     937         self.corpus_count = corpus_count
#     938         self.corpus_total_words = total_words
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/word2vec.py in scan_vocab(self, sentences, corpus_file, progress_per, workers, trim_rule)
#    1569             sentences = LineSentence(corpus_file)
#    1570
# -> 1571         total_words, corpus_count = self._scan_vocab(sentences, progress_per, trim_rule)
#    1572
#    1573         logger.info(
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/word2vec.py in _scan_vocab(self, sentences, progress_per, trim_rule)
#    1552                     sentence_no, total_words, len(vocab)
#    1553                 )
# -> 1554             for word in sentence:
#    1555                 vocab[word] += 1
#    1556             total_words += len(sentence)
#
# TypeError: 'Text' object is not iterable
